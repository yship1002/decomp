# %%
from NSPLIB.src.instances.EDUnit.EDUnits import const_model

from src.models.cz_model import CaoZavalaModel, CaoZavalaAlgo
import cProfile
import numpy as np
from pyomo.environ import *
# UBD:106451

sto_m = const_model()
m = CaoZavalaModel.from_sto_m(sto_m)
m.build()
eps=10
# EDUnits_obj=106.451
# EDUnits_sol={
#    "concStream3": [100-eps,100+eps],
#    "concStream5": [97.52475600962396-eps,97.52475600962396+eps],
#     "concStream6": [93.33645327361674-eps,93.33645327361674+eps],
#     "concStream8": [64.39428575130025-eps,64.39428575130025+eps],
#     "flowStream3": [0.022359190491272524,0.022359190491272524+eps],
#     "flowStream5": [0.004560651742154918, 0.004560651742154918 +eps],
#     "flowStream6": [0.022286458333333335,0.022286458333333335+eps],
#     "flowStream8": [0.004487919584215729,0.004487919584215729 +eps]
# }

# EDUnits_sol={
#     "flowStream3" : [ 0.001  ,  1000000 ],
#     "concStream3" : [ 0.001  ,  100 ],
#     "flowStream5" : [ 0.001  ,  1000000 ],
#     "concStream5" : [ 0.001  ,  100 ],
#     "flowStream6" : [ 0.001  ,  1000000 ],
#     "concStream6" : [ 0.001  ,  100 ],
#     "flowStream8" : [ 0.001  ,  1000000 ],
#     "concStream8" : [ 0.001  ,  100 ]
# }
# m.update_y_bound(EDUnits_sol)

tol=1e-3
from pyomo.opt import SolverFactory
solver=SolverFactory("baron",options = {'EpsA': 100*tol, 'AbsConFeasTol': 1*tol, 'TDo':0, 'MDo':0,'OBTTDo':1})
solver.solve(m.aux_models["lbd"][3],tee=True)
m.aux_models["lbd"][3].pprint()
0.303787+0.139+1.85

# alg=CaoZavalaAlgo(m,solver="baron")
# alg.solve(max_iter=1e8, max_time=3600*12, tol=1e-3,ubd_provided=106.451)
# Out:
# ===========================================================================
#  BARON version 26.4.12. Built: OSX-64 2026-04-12 13:07:21
#  Running on machine Jingzhis-MacBook-Air.local
#
#  BARON is a product of The Optimization Firm. For more information and
#  related optimization and data analytics products visit https://minlp.com.
#
#  Licensee: Jingzhi Yang at University of System of Georgia, jyang872@gatech.edu.
#
#  If you publish work using this software, please cite publications from
#  https://minlp.com/baron-publications, such as:
#
#  Zhang, Y. and N. V. Sahinidis, Solving continuous and discrete
#  nonlinear programs with BARON, Comput Optim Appl, 92, 1123-1161, 2025.
#  https://doi.org/10.1007/s10589-024-00633-0
# ===========================================================================
#  This BARON run may utilize the following subsolver(s)
#  For LP/MIP/QP: CLP/CBC, ILOG CPLEX
#  For NLP: IPOPT, FILTERSQP
# ===========================================================================
#  Doing local search
#  Preprocessing found feasible solution with value 1.85055
#  Solving bounding LP
#  Starting multi-start local search
#  Done with local search
# ===========================================================================
#   Iteration       Time (s)     Mem   Lower bound     Upper bound   Progress
#           1           0.09    12MB     1.85055         1.85055      100.00%
#
#                          *** Normal completion ***
#
#  Wall clock time:                     0.15
#  Total CPU time used:                 0.10
#
#  Total no. of BaR iterations:         1
#  Best solution found at node:        -1
#  Max. no. of nodes in memory:         1
#
#  All done
# ===========================================================================
# 2 Var Declarations
#     x : Size=19, Index={3}*{I, flowSplit, memLength, memWidth, thicknessConcentrate, thicknessDilute, flowOutConcentrateND, flowOutDiluteND, concOutConcentrateND, concOutDiluteND, voltCellPair, resConcentrate, resDilute, voltNonOhmicCEM, voltNonOhmicAEM, capex, opex1, opex2, costTotal}
#         Key                         : Lower : Value                  : Upper     : Fixed : Stale : Domain
#                            (3, 'I') :   0.1 :     1.0357737761033001 :    1000.0 : False : False : NonNegativeReals
#                        (3, 'capex') :     0 :     286.16259441684224 : 1000000.0 : False : False : NonNegativeReals
#         (3, 'concOutConcentrateND') :     1 :      21.96193264789755 :       100 : False : False : NonNegativeReals
#              (3, 'concOutDiluteND') : 0.001 :      1.000000000088357 :         1 : False : False : NonNegativeReals
#                    (3, 'costTotal') :     0 :                   None : 1000000.0 : False :  True : NonNegativeReals
#         (3, 'flowOutConcentrateND') : 0.001 :   0.000999999900008164 :       100 : False : False : NonNegativeReals
#              (3, 'flowOutDiluteND') : 0.001 :      9.999999988426422 :        10 : False : False : NonNegativeReals
#                    (3, 'flowSplit') :     0 : -9.999985239316007e-11 :         1 : False : False : NonNegativeReals
#                    (3, 'memLength') :  0.01 :     0.2689498094679999 :       100 : False : False : NonNegativeReals
#                     (3, 'memWidth') :  0.01 :   0.009999999900157824 :        10 : False : False : NonNegativeReals
#                        (3, 'opex1') :     0 :     1563.8503858663773 : 1000000.0 : False : False : NonNegativeReals
#                        (3, 'opex2') :     0 :      0.537015608005614 : 1000000.0 : False : False : NonNegativeReals
#               (3, 'resConcentrate') : 1e-08 :  5.969464950308511e-05 :         1 : False : False : NonNegativeReals
#                    (3, 'resDilute') : 1e-08 :  0.0006846972630415203 :         1 : False : False : NonNegativeReals
#         (3, 'thicknessConcentrate') : 0.001 :  0.0009999999000076386 :         1 : False : False : NonNegativeReals
#              (3, 'thicknessDilute') : 0.001 :  0.0009999999000142427 :         1 : False : False : NonNegativeReals
#                 (3, 'voltCellPair') :     0 :     0.6044308019694836 :         5 : False : False : NonNegativeReals
#              (3, 'voltNonOhmicAEM') : 1e-07 :    0.07578420361706917 :         1 : False : False : NonNegativeReals
#              (3, 'voltNonOhmicCEM') : 1e-07 :    0.07636728258250378 :         1 : False : False : NonNegativeReals
#     y : Size=8, Index={flowStream3, concStream3, flowStream5, concStream5, flowStream6, concStream6, flowStream8, concStream8}
#         Key         : Lower : Value                : Upper   : Fixed : Stale : Domain
#         concStream3 : 0.001 :                 None :     100 : False :  True : NonNegativeReals
#         concStream5 : 0.001 :     97.7291662937074 :     100 : False : False : NonNegativeReals
#         concStream6 : 0.001 :                 None :     100 : False :  True : NonNegativeReals
#         concStream8 : 0.001 :    97.52475601824096 :     100 : False : False : NonNegativeReals
#         flowStream3 : 0.001 :                 None : 1000000 : False :  True : NonNegativeReals
#         flowStream5 : 0.001 : 0.022288686953150415 : 1000000 : False : False : NonNegativeReals
#         flowStream6 : 0.001 :                 None : 1000000 : False :  True : NonNegativeReals
#         flowStream8 : 0.001 : 0.022286458307539926 : 1000000 : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 0.001*(x[3,capex] + x[3,opex1] + x[3,opex2])
#
# 17 Constraint Declarations
#     g_3_0 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                       : Upper : Active
#         None :   0.0 : 0.01496*x[3,resConcentrate]*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5])) - x[3,thicknessConcentrate] :   0.0 :   True
#     g_3_1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                        : Upper : Active
#         None :   0.0 : 0.01496*x[3,resDilute]*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5])) - x[3,thicknessDilute] :   0.0 :   True
#     g_3_10 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                  : Upper : Active
#         None :  -Inf : x[3,I]/(x[3,memLength]*x[3,memWidth]*(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute]))) - 1 :   0.0 :   True
#     g_3_11 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                  : Upper : Active
#         None :   0.0 : x[3,capex] - (6800*x[3,memLength]*x[3,memWidth] + 99600*x[3,memLength]*x[3,memWidth]) :   0.0 :   True
#     g_3_12 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                        : Upper : Active
#         None :   0.0 : x[3,opex1] - 0.00195528*(2.5e-05*x[3,I]/(x[3,memLength]*x[3,memWidth]) + 500*x[3,voltCellPair])*x[3,I]*2555 :   0.0 :   True
#     g_3_13 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                : Upper : Active
#         None :   0.0 : x[3,opex2] - 0.00195528*(1000*(1400/(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001))*x[3,memLength]*(scaleFacFlow[3]*x[3,flowOutConcentrateND]/x[3,memWidth])**2/(4*x[3,thicknessConcentrate])*((scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/2) + 1000*(104.5/(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.37)*x[3,memLength]*(scaleFacFlow[3]*x[3,flowOutDiluteND]/x[3,memWidth])**2/(4*x[3,thicknessDilute])*((scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/2))*500*2555 :   0.0 :   True
#     g_3_14 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                        : Upper : Active
#         None :   0.0 : x[3,concOutConcentrateND] - 30000/(scaleFacConc[3]*14.0067) :  +Inf :   True
#     g_3_15 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                      : Upper : Active
#         None :   0.0 : y[flowStream8] - scaleFacFlow[3]*500*x[3,flowOutDiluteND] :   0.0 :   True
#     g_3_16 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                  : Upper : Active
#         None :   0.0 : y[concStream8] - scaleFacConc[3]*x[3,concOutDiluteND] :   0.0 :   True
#     g_3_2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                : Upper : Active
#         None :   0.0 : exp(43.248789133323825*x[3,voltNonOhmicCEM])*(0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute]))))) - 0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))) :   0.0 :   True
#     g_3_3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                : Upper : Active
#         None :   0.0 : exp(43.248789133323825*x[3,voltNonOhmicAEM])*(0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute]))))) - 0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))) :   0.0 :   True
#     g_3_4 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#         None :   0.0 : x[3,flowOutConcentrateND] - x[3,flowSplit]*y[flowStream5]/500/scaleFacFlow[3] - (8.662095632777777e-11*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute]))))) + 1.0727778216111111e-10*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute]))))) + waterTransNumber*(0.8999999999999999*(x[3,I]/(x[3,memLength]*x[3,memWidth]*96485.3321)) - 9.523809523809524e-09*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]* ...
#     g_3_5 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#         None :   0.0 : x[3,flowOutDiluteND] - (1 - x[3,flowSplit])*y[flowStream5]/500/scaleFacFlow[3] + (8.662095632777777e-11*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute]))))) + 1.0727778216111111e-10*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute]))))) + waterTransNumber*(0.8999999999999999*(x[3,I]/(x[3,memLength]*x[3,memWidth]*96485.3321)) - 9.523809523809524e-09*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3] ...
#     g_3_6 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           : Upper : Active
#         None :   0.0 : x[3,flowOutConcentrateND]*x[3,concOutConcentrateND] - x[3,flowSplit]*y[flowStream5]/500*y[concStream5]/(scaleFacFlow[3]*scaleFacConc[3]) - (0.8999999999999999*(x[3,I]/(x[3,memLength]*x[3,memWidth]*96485.3321)) - 9.523809523809524e-09*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute]))))) - 9.09090909090909e-09*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute]))))))*x[3,memLength]*x[3,memWidth]/(scaleFacFlow[3]*scaleFacConc[3]) :   0.0 :   True
#     g_3_7 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       : Upper : Active
#         None :   0.0 : x[3,flowOutDiluteND]*x[3,concOutDiluteND] - (1 - x[3,flowSplit])*y[flowStream5]/500*y[concStream5]/(scaleFacFlow[3]*scaleFacConc[3]) + (0.8999999999999999*(x[3,I]/(x[3,memLength]*x[3,memWidth]*96485.3321)) - 9.523809523809524e-09*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.8819999999999999*x[3,thicknessDilute]))))) - 9.09090909090909e-09*(0.5*(x[3,concOutConcentrateND]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))*scaleFacConc[3] + y[concStream5]*(1 + x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutConcentrateND] + x[3,flowSplit]*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessConcentrate]))*(2*x[3,thicknessConcentrate])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutConcentrateND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessConcentrate])))) - 0.5*(x[3,concOutDiluteND]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute])))*scaleFacConc[3] + y[concStream5]*(1 - x[3,I]/(x[3,memLength]*x[3,memWidth])/(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute]))))))*x[3,memLength]*x[3,memWidth]/(scaleFacFlow[3]*scaleFacConc[3]) :   0.0 :   True
#     g_3_8 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                   : Upper : Active
#         None :   0.0 : x[3,voltCellPair] - (x[3,voltNonOhmicCEM] + x[3,voltNonOhmicAEM]) - (x[3,resConcentrate] + x[3,resDilute] + 0.00025 + 0.00018)*(x[3,I]/(x[3,memLength]*x[3,memWidth])) :   0.0 :   True
#     g_3_9 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                  : Upper : Active
#         None :  -Inf : x[3,I]/(x[3,memLength]*x[3,memWidth]*(0.29*(1000*(0.5*(scaleFacFlow[3]*x[3,flowOutDiluteND] + (1 - x[3,flowSplit])*y[flowStream5]/500)/(x[3,memWidth]*x[3,thicknessDilute]))*(2*x[3,thicknessDilute])/0.001)**0.5*7.991165375750967*(0.5*(scaleFacConc[3]*x[3,concOutDiluteND] + y[concStream5]))*96485.3321*1.84e-09/(0.9179999999999999*x[3,thicknessDilute]))) - 1 :   0.0 :   True
#
# 20 Declarations: y x obj g_3_0 g_3_1 g_3_2 g_3_3 g_3_4 g_3_5 g_3_6 g_3_7 g_3_8 g_3_9 g_3_10 g_3_11 g_3_12 g_3_13 g_3_14 g_3_15 g_3_16
# 2.292787
