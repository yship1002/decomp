# %%
from NSPLIB.src.instances.EDUnit.EDUnits import const_model

from src.models.cz_model import CaoZavalaModel, CaoZavalaAlgo
import cProfile
import numpy as np
from pyomo.environ import *

sto_m = const_model()
m = CaoZavalaModel.from_sto_m(sto_m)
m.build()
alg=CaoZavalaAlgo(m,solver="baron")
alg.solve(max_iter=1e8, max_time=3600*12, tol=1e-2,ubd_midpt_fix=1,ubd_local_solve=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 import numpy as np
#       6 from pyomo.environ import *
# ----> 8 sto_m = const_model()
#       9 m = CaoZavalaModel.from_sto_m(sto_m)
#      10 m.build()
#
# File ~/Desktop/decomp/NSPLIB/src/instances/EDUnit/EDUnits.py:603, in const_model()
#     593 objs = {s: _obj for s in scenarios}
#     594 _content = {
#     595     'pm': pm,
#     596     'y_set': var1_names,
#    (...)
#     600     'obj_sense': 1
#     601 }
# --> 603 sto_m = builder.build(**_content)
#     605 return sto_m
#
# File ~/Desktop/decomp/NSPLIB/src/main.py:100, in StoModelBuilder.build(self, pm, y_set, x_set, scenarios, con_1, con_2, y_bound, x_bound, objs, obj_sense, y_domain, x_domain, y_init, x_init)
#      98     builder = _StoModelPyomoBuilder()
#      99     builder.add_meta(self.name, self.type)
# --> 100     builder.build(pm, y_set, con_1, scenarios, objs, obj_sense)
#     102 # direct build
#     103 else:
#     105     builder = _StoModelDirectBuilder()
#
# File ~/Desktop/decomp/NSPLIB/src/main.py:468, in _StoModelPyomoBuilder.build(self, pm, var1_names, con1_names, scenarios, objs, obj_sense)
#     465     _obj = getattr(pm, obj_name)
#     467     # 11.3. store the updated expressions
# --> 468     obj_expr[scenario] = replace_expressions(_obj, var_map)
#     470 # 11.4. sum up the expressions
#     471 overall_obj = sum(v for v in obj_expr.values())
#
# File ~/Desktop/decomp/pyomo/pyomo/core/expr/visitor.py:989, in replace_expressions(expr, substitution_map, descend_into_named_expressions, remove_named_expressions)
#     960 def replace_expressions(
#     961     expr,
#     962     substitution_map,
#     963     descend_into_named_expressions=True,
#     964     remove_named_expressions=True,
#     965 ):
#     966     """
#     967
#     968     Parameters
#    (...)
#     983        Pyomo expression : returns the new expression object
#     984     """
#     985     return ExpressionReplacementVisitor(
#     986         substitute=substitution_map,
#     987         descend_into_named_expressions=descend_into_named_expressions,
#     988         remove_named_expressions=remove_named_expressions,
# --> 989     ).walk_expression(expr)
#
# File ~/Desktop/decomp/pyomo/pyomo/core/expr/visitor.py:276, in StreamBasedExpressionVisitor.walk_expression(self, expr)
#     273     root = expr
#     275 try:
# --> 276     result = self._process_node(root, RECURSION_LIMIT)
#     277     _nonrecursive = None
#     278 except RevertToNonrecursive:
#
# File ~/Desktop/decomp/pyomo/pyomo/core/expr/visitor.py:359, in StreamBasedExpressionVisitor._process_node_general(self, node, recursion_limit)
#     356         descend, child_result = tmp
#     358 if descend:
# --> 359     child_result = self._process_node(child, recursion_limit)
#     361 if self.acceptChildResult is not None:
#     362     data = self.acceptChildResult(node, data, child_result, child_idx)
#
# File ~/Desktop/decomp/pyomo/pyomo/core/expr/visitor.py:379, in StreamBasedExpressionVisitor._process_node_general(self, node, recursion_limit)
#     376 # We are done with this node.  Call exitNode to compute
#     377 # any result
#     378 if self.exitNode is not None:
# --> 379     return self.exitNode(node, data)
#     380 else:
#     381     return data
#
# File ~/Desktop/decomp/pyomo/pyomo/core/expr/visitor.py:1077, in ExpressionReplacementVisitor.exitNode(self, node, data)
#    1075 elif data[0]:
#    1076     if data[2]:
# -> 1077         return node._apply_operation(data[1])
#    1078     else:
#    1079         return node.create_node_with_local_data(data[1])
#
# File ~/Desktop/decomp/pyomo/pyomo/core/expr/numeric_expr.py:1212, in SumExpression._apply_operation(self, result)
#    1210 if result:
#    1211     _iter = iter(result)
# -> 1212     return sum(_iter, start=next(_iter))
#    1213 else:
#    1214     return 0
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
