# %%
import matplotlib.pyplot as plt
import numpy as np

eps_list = np.logspace(1,-2,4)
distances0=[24.584292802992323,0.3610660777352024,0.0035885698387545517,3.474408588033384e-05]
distances10=[29.621658257730914,
  0.9994334720345392,
  0.06720126518771963,
  0.006612050186788565]
distances1=[23.735587858798297,
  0.4249826832610921,
  0.01000217965618333,
  0.0009618129592183777]
distances01=[23.14698304671832,
  0.3675385019081716,
  0.004284491778946631,
  0.0003970840518405794]
plt.loglog(eps_list, distances0,color='red',label='perturb 0%')
plt.loglog(eps_list, distances01,color='orange',label='perturb 0.1%')
plt.loglog(eps_list, distances1,color='green',label='perturb 1%')
plt.loglog(eps_list, distances10,color='blue',label='perturb 10%')
plt.legend(fontsize=15)
plt.xlabel('Diameter', fontsize=18)
plt.ylabel('Error', fontsize=18)
plt.xticks([1e1,1e0,1e-1,1e-2],fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.savefig("graphing/LG_perturb.eps", format="eps", dpi=1200, bbox_inches="tight")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
