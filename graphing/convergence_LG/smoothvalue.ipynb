# %%
from graphing.helper import convergence_analysis
from NSPLIB.src.instances.illustrative_examples.fig12 import const_model
from src.models.lagrangean_model import LagrangeanModel, LagrangeanAlgo
import copy
fig12_obj=-0.14586
fig12_sol={0: 2.6199679213876177}
sto_m = const_model()
m = LagrangeanModel.from_sto_m(sto_m)
m.build()
alg = LagrangeanAlgo(m,lag_iter=200, solver='baron')
handle=convergence_analysis(alg,fig12_sol,fig12_obj,start=-3,stop=0,steps=4)
handle.savefig("graphing/convergence_LG/smoothvalue.eps", format="eps", dpi=1200,bbox_inches="tight")
# Out:
# Calculating the Hausdorff distances...
# 	diameter = 1.0E+00, distance = 5.21E-01
# 	diameter = 1.0E-01, distance = 9.20E-02
# 	diameter = 1.0E-02, distance = 3.32E-03
# 	diameter = 1.0E-03, distance = 1.04E-03
# Done!
# Convergence Order:0.9545221288373791 prefactor K:0.5449325278903958

# %%
from graphing.helper import convergence_analysis
from NSPLIB.src.instances.illustrative_examples.fig12 import const_model
from src.models.lagrangean_model import LagrangeanModel, LagrangeanAlgo
import copy
fig12_obj=-0.14586
fig12_sol={0: 2.6199679213876177}
sto_m = const_model()
m = LagrangeanModel.from_sto_m(sto_m)
m.build()
alg = LagrangeanAlgo(m,lag_iter=50, solver='baron')
handle=convergence_analysis(alg,fig12_sol,fig12_obj,start=-3,stop=0,steps=4)
# Out:
# Calculating the Hausdorff distances...
# iter 0 stepsize 0.001
#
# iter 1 stepsize 0.001
#
# iter 2 stepsize 0.001
#
# iter 3 stepsize 0.001
#
# iter 4 stepsize 0.001
#
# iter 5 stepsize 0.00067
#
# iter 6 stepsize 0.0004489
#
# iter 7 stepsize 0.000300763
#
# iter 8 stepsize 0.00020151121
#
# iter 9 stepsize 0.0001350125107
#
# iter 10 stepsize 9.045838216900001e-05
#
# iter 11 stepsize 6.060711605323001e-05
#
# iter 12 stepsize 4.060676775566411e-05
#
# iter 13 stepsize 2.7206534396294953e-05
#
# iter 14 stepsize 1.822837804551762e-05
#
# iter 15 stepsize 1.2213013290496806e-05
#
# iter 16 stepsize 8.18271890463286e-06
#
# iter 17 stepsize 5.482421666104016e-06
#
# iter 18 stepsize 3.673222516289691e-06
#
# iter 19 stepsize 2.461059085914093e-06
#
# iter 20 stepsize 1.6489095875624425e-06
#
# iter 21 stepsize 1.1047694236668366e-06
#
# iter 22 stepsize 7.401955138567805e-07
#
# iter 23 stepsize 4.95930994284043e-07
#
# iter 24 stepsize 3.3227376617030884e-07
#
# ...
