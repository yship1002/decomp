# %%
import dill
import matplotlib.pyplot as plt
with open('data/tanksize.pkl', 'rb') as f:
    data = dill.load(f)
data.res.plot_bb_n_gap("loglog")
plt.savefig("graphing/node_analysis/Node_tanksize.eps", format="eps", dpi=1200)
