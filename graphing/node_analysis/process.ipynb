# %%
import dill
import matplotlib.pyplot as plt
with open('data/process.pkl', 'rb') as f:
    data = dill.load(f)
data.res.plot_bb_n_gap("loglog")
plt.savefig("graphing/node_analysis/Node_process.eps", format="eps", dpi=1200)
