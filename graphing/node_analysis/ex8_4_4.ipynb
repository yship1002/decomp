# %%
import dill
import matplotlib.pyplot as plt
with open('data/ex8_4_4.pkl', 'rb') as f:
    data = dill.load(f)
data.res.plot_bb_n_gap("loglog")
plt.savefig("graphing/node_analysis/Node_ex8_4_4.eps", format="eps", dpi=1200)
