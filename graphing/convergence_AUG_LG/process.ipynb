# %%
from graphing.helper import convergence_analysis
from src.models.lagrangean_model import LagrangeanModel, LagrangeanAlgo
from NSPLIB.src.instances.process.process_SP import const_model
process_obj = -1126.4218270121305
process_sol = {"x1":1727.2601809997955,"x2":16000,"x3":104.23841082714829,"x5":2000}
process_y_bound = {"x1":[10,2000],"x2":[0,16000],"x3":[0,120],"x5":[0,2000]}
sto_m = const_model()
m = LagrangeanModel.from_sto_m(sto_m)
m.build()
alg = LagrangeanAlgo(m,lag_iter=0, solver='gurobi')
options = {
    'max_iter': 1e5,
    'max_time': 3600 * 24,
    'tol': 1e-3,
    'ubd_midpt_fix': 1,
    'ubd_local_solve': 1,
    'ubd_provided': process_obj,
    'inherit_multiplier': True,
    'aug_lag': True,
    'aug_lag_iter': 3,
    "aug_lag_p":1
}
handle=convergence_analysis(alg,process_sol,process_obj,start=-4,stop=0,steps=5)
# handle.savefig("graphing/convergence_LG/process.eps", format="eps", dpi=1200,bbox_inches="tight")
# Out:
# Calculating the Hausdorff distances...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-15
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# 	diameter = 1.0E+00, distance = 2.60E+00
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# 	diameter = 1.0E-01, distance = 3.20E-01
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# 	diameter = 1.0E-02, distance = 3.21E-02
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# 	diameter = 1.0E-03, distance = 3.21E-03
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# Set parameter LogToConsole to value 1
# Set parameter LogToConsole to value 0
# 	diameter = 1.0E-04, distance = -INF
# Done!
# /Users/jyang872/Desktop/decomp/graphing/helper.py:14: RuntimeWarning: invalid value encountered in log10
#   log_distances = np.log10(distances)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 23
#      10 alg = LagrangeanAlgo(m,lag_iter=0, solver='gurobi')
#      11 options = {
#      12     'max_iter': 1e5,
#      13     'max_time': 3600 * 24,
#    (...)
#      21     "aug_lag_p":1
#      22 }
# ---> 23 handle=convergence_analysis(alg,process_sol,process_obj,start=-4,stop=0,steps=5)
#      24 # handle.savefig("graphing/convergence_LG/process.eps", format="eps", dpi=1200,bbox_inches="tight")
#
# File ~/Desktop/decomp/graphing/helper.py:17, in convergence_analysis(alg, fixed_pt, optimal_sol, start, stop, steps)
#      14 log_distances = np.log10(distances)
#      16 # Perform curve fitting
# ---> 17 params, _ = curve_fit(linear_func, log_eps, log_distances)
#      18 print(f"Convergence Order:{params[0]} prefactor K:{10**params[1]}")
#      19 plt.loglog(eps_list, distances)
#
# File ~/anaconda3/envs/pyomo/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:930, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     928 # optimization may produce garbage for float32 inputs, cast them to float64
#     929 if check_finite:
# --> 930     ydata = np.asarray_chkfinite(ydata, float)
#     931 else:
#     932     ydata = np.asarray(ydata, float)
#
# File ~/anaconda3/envs/pyomo/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:646, in asarray_chkfinite(a, dtype, order)
#     644 a = asarray(a, dtype=dtype, order=order)
#     645 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 646     raise ValueError(
#     647         "array must not contain infs or NaNs")
#     648 return a
#
# ValueError: array must not contain infs or NaNs
