# %%
from graphing.helper import convergence_analysis
from src.models.cz_model import CaoZavalaModel, CaoZavalaAlgo
from NSPLIB.src.instances.poutil.poutil_SP import const_model
poutil_obj = 266187.5332404778  # Replace with actual value
poutil_sol = {'alpha': 74.94473247856709, 'beta': 9.000000000000028}  # Replace with actual solution values
poutil_y_bound = {'alpha': [0.0, 470], 'beta': [0.0, 470]}  # Replace with actual bounds
sto_m = const_model()
m = CaoZavalaModel.from_sto_m(sto_m)
m.build()
alg=CaoZavalaAlgo(m,solver="baron")
handle=convergence_analysis(alg,poutil_sol,poutil_obj,start=-5,stop=0,steps=6)
handle.savefig("graphing/convergence_CZ/poutil.eps", format="eps", dpi=1200,bbox_inches="tight")
# Out:
# Calculating the Hausdorff distances...
# 	diameter = 1.0E+00, distance = 1.15E+02
# 	diameter = 1.0E-01, distance = 1.95E+01
# 	diameter = 1.0E-02, distance = 2.04E+00
# 	diameter = 1.0E-03, distance = 2.04E-01
# 	diameter = 1.0E-04, distance = 2.04E-02
# 	diameter = 1.0E-05, distance = 2.04E-03
# Done!
# Convergence Order:0.9625178184231246 prefactor K:148.20173993708875
