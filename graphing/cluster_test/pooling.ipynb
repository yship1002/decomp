# %%
import dill
import matplotlib.pyplot as plt
from graphing.cluster_test.node_plot import node_plot
with open('/Users/jyang872/Desktop/decomp/data/cluster_test/pooling.pkl', 'rb') as f:
    data = dill.load(f)
handle=node_plot(data.res)
handle.savefig("graphing/cluster_test/ClusterTest_pooling.eps", format="eps", dpi=1200)
