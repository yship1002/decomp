# %%
from graphing.helper import convergence_analysis
from src.models.cz_model import CaoZavalaAlgo, CaoZavalaModel
from NSPLIB.src.instances.process.process_SP import const_model
import numpy as np
from src.models.bb_node import BranchBoundNode
process_obj = -1126.4218270121305
process_sol = {"x1":1727.2601809997955,"x2":16000,"x3":104.23841082714829,"x5":2000}
process_y_bound = {"x1":[10,2000],"x2":[0,16000],"x3":[0,120],"x5":[0,2000]}
process_y_bound={'x1': [1005.0, 2000], 'x2': [8000.0, 16000], 'x3': [60.0, 120], 'x5': [0, 2000]}
sto_m = const_model()
m = CaoZavalaModel.from_sto_m(sto_m)
m.build()
m.update_y_bound(process_y_bound)
from pyomo.opt import SolverFactory
solver=SolverFactory("gurobi_direct_minlp")
solver.solve(m.aux_models["lbd"][0],tee=True)
# alg=CaoZavalaAlgo(m,solver="baron")
# alg.solve(max_iter=1e5, max_time=3600*24, tol=1e-3,ubd_local_solve=1,ubd_midpt_fix=0,ubd_provided=process_obj)
# Out:
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.2.0 25C5048a)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7 rows, 13 columns and 13 nonzeros
# Model fingerprint: 0x977bad5f
# Model has 1 quadratic objective term
# Model has 1 quadratic constraint
# Model has 3 general nonlinear constraints (6 nonlinear terms)
# Variable types: 13 continuous, 0 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 3e+00]
#   QMatrix range    [4e-02, 4e-02]
#   QLMatrix range   [3e-01, 1e+00]
#   Objective range  [1e-02, 3e+00]
#   QObjective range [4e-02, 4e-02]
#   Bounds range     [1e+00, 2e+04]
#   RHS range        [1e+00, 1e+02]
#   QRHS range       [6e+01, 6e+01]
# Presolve model has 3 nlconstr
# Added 10 variables to disaggregate expressions.
# Presolve removed 4 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 39 rows, 25 columns, 106 nonzeros
# Presolved model has 8 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 25 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -385.2177007
#
# Root relaxation: objective -5.614549e+02, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -561.45493    0    7 -385.21770 -561.45493  45.8%     -    0s
#      0     0 -524.65879    0    7 -385.21770 -524.65879  36.2%     -    0s
#      0     0 -461.72216    0    7 -385.21770 -461.72216  19.9%     -    0s
#      0     0 -459.48435    0    7 -385.21770 -459.48435  19.3%     -    0s
#      0     0 -446.96133    0    7 -385.21770 -446.96133  16.0%     -    0s
#      0     0 -446.91967    0    7 -385.21770 -446.91967  16.0%     -    0s
#      0     0 -442.73987    0    7 -385.21770 -442.73987  14.9%     -    0s
#      0     2 -442.73987    0    7 -385.21770 -442.73987  14.9%     -    0s
# *  911    47              32    -385.2177008 -385.22431  0.00%   2.7    0s
#
# Cutting planes:
#   RLT: 6
#
# Explored 938 nodes (2510 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: -385.218
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.852177007655e+02, best bound -3.852243097333e+02, gap 0.0017%
# {'Problem': [{'Lower bound': -385.22430973332524, 'Upper bound': -385.21770076548273, 'Number of objectives': 1, 'Number of constraints': nan, 'Number of variables': nan, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'Termination condition': 'optimal', 'Termination message': 'TerminationCondition.convergenceCriteriaSatisfied', 'Root node time': -100}], 'Solution': [OrderedDict({'number of solutions': 0, 'number of solutions displayed': 0})]}

# %%
-385.2177007282456-370.8358284288175-375.71605324977423
# Out:
# -1131.7695824068373
