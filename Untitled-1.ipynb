# %%
from src.models.lagrangean_model import LagrangeanAlgo,LagrangeanModel
from NSPLIB.src.instances.crude_selection.crude_selection import const_model
from src.models.bb_node import BranchBoundNode
crude_obj = -18350.146929611754
crude_sol = {f'crudeQuantity[{i}]': 0. for i in range(1, 10 + 1)}
crude_sol['crudeQuantity[2]'] = 150.87595641747944
crude_sol['crudeQuantity[3]'] = 201.29570746971186
crude_sol['crudeQuantity[4]'] = 56.18456149457359
crude_sol['crudeQuantity[8]'] = 162.2466500589715
crude_sol['crudeQuantity[10]'] = 18.848116800048512
crude_y_bound = {
    'crudeQuantity[1]': [0, 201.29570747217807],
    'crudeQuantity[2]': [0, 212.48012718600953],
    'crudeQuantity[3]': [0, 201.29570747217807],
    'crudeQuantity[4]': [0, 199.57869634340224],
    'crudeQuantity[5]': [0, 210.54848966613673],
    'crudeQuantity[6]': [0, 222.1383147853736],
    'crudeQuantity[7]': [0, 196.7885532591415],
    'crudeQuantity[8]': [0, 208.54531001589828],
    'crudeQuantity[9]': [0, 204.3720190779014],
    'crudeQuantity[10]': [0, 210.2623211446741]
}
crude_y_bound = {
    'crudeQuantity[1]': [0, 0],
    'crudeQuantity[2]': [150.5, 151],
    'crudeQuantity[3]': [200, 201.29570747217807],
    'crudeQuantity[4]': [56, 56.5],
    'crudeQuantity[5]': [0, 0],
    'crudeQuantity[6]': [0, 0],
    'crudeQuantity[7]': [0, 0],
    'crudeQuantity[8]': [162, 162.5],
    'crudeQuantity[9]': [0, 0],
    'crudeQuantity[10]': [18.5, 19]
}

sto_m = const_model()
m = LagrangeanModel.from_sto_m(sto_m)
m.build()
binary_ys = [f'pickCrude[{i}]' for i in range(1, 10 + 1)]
binary_y_val = {y: 0 for y in binary_ys}
binary_y_val['pickCrude[2]'] = 1
binary_y_val['pickCrude[3]'] = 1
binary_y_val['pickCrude[4]'] = 1
binary_y_val['pickCrude[8]'] = 1
binary_y_val['pickCrude[10]'] = 1
m.fix_binary_y(binary_y_val)

m.update_y_bound(crude_y_bound)

options = {
    'max_iter': 1e5,
    'max_time': 3600 * 24,
    'tol': 1e-3,
    'ubd_midpt_fix': 1,
    'ubd_local_solve': 1,
    'ubd_provided': crude_obj,
    'inherit_multiplier': True,
    'aug_lag': True,
    'aug_lag_iter': 3,
    "aug_lag_p":5
}

alg = LagrangeanAlgo(m,lag_iter=0, solver='baron')
# alg.solve(**options)
a =BranchBoundNode(crude_y_bound)
print(alg.calc_lbd(a,**options))
options["aug_lag"]=False
alg = LagrangeanAlgo(m,lag_iter=3, solver='baron')
a =BranchBoundNode(crude_y_bound)
print(alg.calc_lbd(a,**options))
# Out:
# augmented lagrangean iteration 0
# augmented lagrangean iteration 1
# augmented lagrangean iteration 2
# -18392.592752498473
# Lagrangean iter: 1 Lower bound: -18396.059046042854
# Lagrangean iter: 2 Lower bound: -18396.05903792491
# Lagrangean iter: 3 Lower bound: -18396.059029765394
# -18396.059025673763

# %%
from src.models.lagrangean_model import LagrangeanAlgo,LagrangeanModel
from NSPLIB.src.instances.crude_selection.crude_selection import const_model
from src.models.bb_node import BranchBoundNode
crude_obj = -18350.146929611754
crude_sol = {f'crudeQuantity[{i}]': 0. for i in range(1, 10 + 1)}
crude_sol['crudeQuantity[2]'] = 150.87595641747944
crude_sol['crudeQuantity[3]'] = 201.29570746971186
crude_sol['crudeQuantity[4]'] = 56.18456149457359
crude_sol['crudeQuantity[8]'] = 162.2466500589715
crude_sol['crudeQuantity[10]'] = 18.848116800048512
crude_y_bound = {
    'crudeQuantity[1]': [0, 201.29570747217807],
    'crudeQuantity[2]': [0, 212.48012718600953],
    'crudeQuantity[3]': [0, 201.29570747217807],
    'crudeQuantity[4]': [0, 199.57869634340224],
    'crudeQuantity[5]': [0, 210.54848966613673],
    'crudeQuantity[6]': [0, 222.1383147853736],
    'crudeQuantity[7]': [0, 196.7885532591415],
    'crudeQuantity[8]': [0, 208.54531001589828],
    'crudeQuantity[9]': [0, 204.3720190779014],
    'crudeQuantity[10]': [0, 210.2623211446741]
}
crude_y_bound = {
    'crudeQuantity[1]': [0, 0],
    'crudeQuantity[2]': [150, 151],
    'crudeQuantity[3]': [200, 201.29570747217807],
    'crudeQuantity[4]': [56, 57],
    'crudeQuantity[5]': [0, 0],
    'crudeQuantity[6]': [0, 0],
    'crudeQuantity[7]': [0, 0],
    'crudeQuantity[8]': [162, 163],
    'crudeQuantity[9]': [0, 0],
    'crudeQuantity[10]': [18, 19]
}

sto_m = const_model()
m = LagrangeanModel.from_sto_m(sto_m)
m.build()
binary_ys = [f'pickCrude[{i}]' for i in range(1, 10 + 1)]
binary_y_val = {y: 0 for y in binary_ys}
binary_y_val['pickCrude[2]'] = 1
binary_y_val['pickCrude[3]'] = 1
binary_y_val['pickCrude[4]'] = 1
binary_y_val['pickCrude[8]'] = 1
binary_y_val['pickCrude[10]'] = 1
m.fix_binary_y(binary_y_val)

m.update_y_bound(crude_y_bound)

options = {
    'max_iter': 1e5,
    'max_time': 3600 * 24,
    'tol': 1e-3,
    'ubd_midpt_fix': 1,
    'ubd_local_solve': 1,
    'ubd_provided': crude_obj,
    'inherit_multiplier': True,
    'aug_lag': False,
    'aug_lag_iter': 3,
    "aug_lag_p":0.01
}

alg_normal = LagrangeanAlgo(m,lag_iter=3, solver='gurobi')
alg_normal.solve(**options)
# a =BranchBoundNode(crude_y_bound)
# print(alg.calc_lbd(a,**options))
# options["aug_lag"]=False
# alg = LagrangeanAlgo(m,lag_iter=3, solver='baron')
# print(alg.calc_lbd(a,**options))
# Out:
# Solving the problem via SBB...
# 	Maximum iteration: 100000.0
# 	Maximum time: 86400
# 	Tolerance: 1E-03
# Initialize the model...
# Lagrangean iter: 1 Lower bound: -18392.408434760426
# Lagrangean iter: 2 Lower bound: -18392.40842729283
# Lagrangean iter: 3 Lower bound: -18392.408420277097
# 	Root node lower bound: -18392.41, upper bound: -18350.15
# 	Total initialization CPU time: 3.66 s
# Done.
# Solving the model...
# ================================================================================
#   iteration     CPU time    wall time  lower bound  upper bound     gap
# Lagrangean iter: 1 Lower bound: -18370.36870590599
# Lagrangean iter: 2 Lower bound: -18370.36871759407
# Lagrangean iter: 3 Lower bound: -18370.368715602002
# Lagrangean iter: 1 Lower bound: -18392.4083974385
# Lagrangean iter: 2 Lower bound: -18392.40840488485
# Lagrangean iter: 3 Lower bound: -18392.40840397709
#          1        10.83        11.21   -18392.4084   -18350.1469   0.2303%
# Lagrangean iter: 1 Lower bound: -18365.0552151737
# Lagrangean iter: 2 Lower bound: -18365.05451708713
# Lagrangean iter: 3 Lower bound: -18365.05451641922
# Lagrangean iter: 1 Lower bound: -18392.408381689125
# Lagrangean iter: 2 Lower bound: -18392.408374221803
# Lagrangean iter: 3 Lower bound: -18392.408366855718
#          2        17.62        18.25   -18392.4084   -18350.1469   0.2303%
# Lagrangean iter: 1 Lower bound: -18367.673378975287
# Lagrangean iter: 2 Lower bound: -18367.673420894294
# Lagrangean iter: 3 Lower bound: -18367.673384247933
# Lagrangean iter: 1 Lower bound: -18391.944519518507
# Lagrangean iter: 2 Lower bound: -18391.944530040815
# Lagrangean iter: 3 Lower bound: -18391.944526543703
#          3        24.61        25.57   -18391.9445   -18350.1469   0.2278%
# Lagrangean iter: 1 Lower bound: -18381.20919565206
# Lagrangean iter: 2 Lower bound: -18381.209199013785
# Lagrangean iter: 3 Lower bound: -18381.209202785503
# Lagrangean iter: 1 Lower bound: -18391.944510522128
# Lagrangean iter: 2 Lower bound: -18391.944513895513
# Lagrangean iter: 3 Lower bound: -18391.944518482902
#          4        31.52        32.75   -18391.9446   -18350.1469   0.2278%
# Lagrangean iter: 1 Lower bound: -18378.71257141031
# Lagrangean iter: 2 Lower bound: -18378.71257571113
# Lagrangean iter: 3 Lower bound: -18378.71260104787
# Lagrangean iter: 1 Lower bound: -18391.767497074336
# Lagrangean iter: 2 Lower bound: -18391.76749551259
# Lagrangean iter: 3 Lower bound: -18391.767492508796
#          5        38.55        40.03   -18391.7675   -18350.1469   0.2268%
# Lagrangean iter: 1 Lower bound: -18379.405872143096
# Lagrangean iter: 2 Lower bound: -18379.405871298666
# Lagrangean iter: 3 Lower bound: -18379.40586940753
#          6        42.24        45.46   -18381.2092   -18350.1469   0.1693%
# Lagrangean iter: 1 Lower bound: inf
# Lagrangean iter: 1 Lower bound: -
# Lagrangean iter: 3 Lower bound: -18370.103936626263
#         25       146.80       167.12   -18370.1039   -18350.1469   0.1088%
# Lagrangean iter: 1 Lower bound: -18364.691308168996
# Lagrangean iter: 2 Lower bound: -18364.690661779605
# Lagrangean iter: 3 Lower bound: -18364.690661903787
# Lagrangean iter: 1 Lower bound: -18370.10392557643
# Lagrangean iter: 2 Lower bound: -18370.103924754945
# Lagrangean iter: 3 Lower bound: -18370.10392368985
#         26       153.71       174.30   -18370.1039   -18350.1469   0.1088%
# Lagrangean iter: 1 Lower bound: -18363.46547908995
# Lagrangean iter: 2 Lower bound: -18363.465478279526
# Lagrangean iter: 3 Lower bound: -18363.465477623104
# Lagrangean iter: 1 Lower bound: -18369.955222011904
# Lagrangean iter: 2 Lower bound: -18369.955227971812
# Lagrangean iter: 3 Lower bound: -18369.95522704929
#         27       160.35       181.21   -18369.9552   -18350.1469   0.1079%
# Lagrangean iter: 1 Lower bound: -18363.746132245997
# Lagrangean iter: 2 Lower bound: -18363.74613981124
# Lagrangean iter: 3 Lower bound: -18363.746146259808
#         28       163.96       186.46   -18368.8217   -18350.1469   0.1018%
# Lagrangean iter: 1 Lower bound: inf
# Lagrangean iter: 1 Lower bound: -18362.619199515346
# Lagrangean iter: 2 Lower bound: -18362.619213804886
# Lagrangean iter: 3 Lower bound: -18362.619213517257
#         29       167.47       191.63   -18368.8182   -18350.1469   0.1017%
# Lagrangean iter: 1 Lower bound: inf
# Lagrangean iter: 1 Lower bound: -18363.416258250258
# Lagrangean iter: 2 Lower bound: -18363.416262383194
# Lagrangean iter: 3 Lower bound: -18363.416261742066
# Lagrangean iter: 1 Lower bound: -18368.81816875693
# Lagrangean iter: 2 Lower bound: -18368.818185492055
# Lagrangean iter: 3 Lower bound: -18368.81818467173
#         30       174.11       198.54   -18368.8182   -18350.1469   0.1018%
# Lagrangean iter: 1 Lower bound: -18362.18884296958
# Lagrangean iter: 2 Lower bound: -18362.18884238778
# Lagrangean iter: 3 Lower bound: -18362.188848392918
# Lagrangean iter: 1 Lower bound: -18368.77882534496
# Lagrangean iter: 2 Lower bound: -18368.778824289493
# Lagrangean iter: 3 Lower bound: -18368.77882377404
#         31       181.29       206.00   -18368.7788   -18350.1469   0.1015%
# Lagrangean iter: 1 Lower bound: -18362.578769554744
# Lagrangean iter: 2 Lower bound: -18362.57875606204
# Lagrangean iter: 3 Lower bound: -18362.57876064748
#         32       184.84       211.46   -18367.7937   -18350.1469   0.0962%
# ================================================================================
#
#
# evaluating object as numeric value: y['crudeQuantity[1]']
#     (object: <class 'pyomo.core.base.var.VarData'>)
# No value for uninitialized VarData object y['crudeQuantity[1]']
# Failed to record solution; no feasible solution from upper bounding.
# Optimal solution found.
#
# total wall time: 211.46 s
# total CPU time: 184.84 s
# Nodes explored in branch-and-bound: 65
# Lagrangean iter: 1 Lower bound: inf
